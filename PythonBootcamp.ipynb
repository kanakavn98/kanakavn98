# %% [markdown]
# <a href="https://colab.research.google.com/github/kanakavn98/kanakavn98/blob/DataVisualizationUsingPython/PythonBootcamp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
import plotly.express as px #for animation

# %%
df = pd.read_csv('/content/diamonds.csv')
# to show the first five rows
df.head()
# to show last 5 rows
#df.tail()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
df.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.539635
# std        1.142135      0.703869
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# max       58.900000     31.800000

# %%
df.shape
# Out:
# (53940, 10)

# %%
df[['carat','cut','clarity','color']]
# Out:
#        carat        cut clarity color
# 0       0.23      Ideal     SI2     E
# 1       0.21    Premium     SI1     E
# 2       0.23       Good     VS1     E
# 3       0.29    Premium     VS2     I
# 4       0.31       Good     SI2     J
# ...      ...        ...     ...   ...
# 53935   0.72      Ideal     SI1     D
# 53936   0.72       Good     SI1     D
# 53937   0.70  Very Good     SI1     D
# 53938   0.86    Premium     SI2     H
# 53939   0.75      Ideal     SI2     D
#
# [53940 rows x 4 columns]

# %%
#filtering observation;
#if we write single df below it will return just the boolean value
df[df['x']==0]
# Out:
#        carat        cut color clarity  depth  table  price    x     y    z
# 11182   1.07      Ideal     F     SI2   61.6   56.0   4954  0.0  6.62  0.0
# 11963   1.00  Very Good     H     VS2   63.3   53.0   5139  0.0  0.00  0.0
# 15951   1.14       Fair     G     VS1   57.5   67.0   6381  0.0  0.00  0.0
# 24520   1.56      Ideal     G     VS2   62.2   54.0  12800  0.0  0.00  0.0
# 26243   1.20    Premium     D    VVS1   62.1   59.0  15686  0.0  0.00  0.0
# 27429   2.25    Premium     H     SI2   62.8   59.0  18034  0.0  0.00  0.0
# 49556   0.71       Good     F     SI2   64.1   60.0   2130  0.0  0.00  0.0
# 49557   0.71       Good     F     SI2   64.1   60.0   2130  0.0  0.00  0.0

# %%
filtering_for_two_variable= df[(df['x']>0) & (df['y']>0)]
filtering_for_two_variable
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53932 rows x 10 columns]

# %%
filtering_for_two_variable[filtering_for_two_variable['x']==0].shape
# Out:
# (0, 10)

# %%
df['x'].median()
# Out:
# 5.7

# %%
df['cut'].value_counts()
# returning unique values
# Out:
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: cut, dtype: int64

# %%
pd.crosstab(df['cut'],df['color'])
# Out:
# color         D     E     F     G     H     I    J
# cut
# Fair        163   224   312   314   303   175  119
# Good        662   933   909   871   702   522  307
# Ideal      2834  3903  3826  4884  3115  2093  896
# Premium    1603  2337  2331  2924  2360  1428  808
# Very Good  1513  2400  2164  2299  1824  1204  678

# %%
df.groupby('cut')['price'].median().sort_values()
# Out:
# cut
# Ideal        1810.0
# Very Good    2648.0
# Good         3050.5
# Premium      3185.0
# Fair         3282.0
# Name: price, dtype: float64

# %%
# define a list of values
a= [3,5,12,9,4]
np.mean(a)
# Out:
# 6.6

# %%
#manually define a function that can find the average given a list
def avg_list(x):
    sum_list= sum(x)
    count_list= len(x)
    return sum_list/count_list

# %%
# calling the function
avg_list(a)
# Out:
# 6.6

# %%
#manually define a function that can find the variance given a list
def variance_list(x):
    avg=avg_list(x)
    n=len(x)
    variance = sum((item-avg) ** 2 for item in x )/(n-1)
    return variance

# %%
variance_list(a)
# Out:
# 14.299999999999999

# %%
attack =[15,20,10,35,30,35,100]
variance_list(attack)
# Out:
# 916.6666666666666

# %%
def stdev_list(x):
  return np.sqrt(variance_list(x))

# %%
stdev_list(attack)
# Out:
# 30.276503540974915

# %%
# writting error function
def variance_list(x):
    if len(x)< 2:
        raise ValueError('not valid data, Please redefine the list')
    avg=avg_list(x)
    n=len(x)
    variance = sum((item-avg) ** 2 for item in x )/(n-1)
    return variance

# %%
# z-score; x is list value as value
def Zscore_list(x,value):
    avg=avg_list(x)
    stdev_x=stdev_list(x)
    return (value-avg)/ stdev_x

# %%
Zscore_list(attack,30)
# Out:
# -0.1651445647689541

# %%
# define the function to sun elementwise sum
def elementwise_sum_list(list1,list2):
  if (len(list1)!= len(list2)):
     raise ValueError('Two lists must have SAME size')
  return [list1[i]+list2[i] for i in range(len(list1))]

# %%
a=[3,5,12,9,4]
d=[1,0,0,1,0]
elementwise_sum_list(a,d)
# Out:
# [4, 5, 12, 10, 4]

# %%
sorted(a)
# Out:
# [3, 4, 5, 9, 12]

# %%
dd= 10.4
int(dd)
# Out:
# 10

# %%
f=dd-int(dd)
f
# Out:
# 0.40000000000000036

# %%
def percentile_list(p,x):
  n=len(x)
  sorted_x= sorted(x)
  loc=(p/100) * (n+1)
  int_part = int(loc)
  fractional_part= loc-int_part

  return sorted_x[int_part -1] + fractional_part * (sorted_x[int_part]-sorted_x[int_part -1])

# %%
salary= [3850,3710,3755,3890,3880,3880,3920,3940,3950,4050,4130,4325]
percentile_list(80,salary)
# Out:
# 4082.0

# %%
# defining sin function animation
# prepare data
time= np.linspace(0,10,100)
frequency=np.linspace(0.5,2.5,20)
# tranforming data into dataframe
data =pd.DataFrame(
    [{
        'Time': t,
        'Value': np.sin(2*np.pi*f*t),
        'Frequency': f
    } for f in frequency for t in time]

)
data.head()
# Out:
#       Time     Value  Frequency
# 0  0.00000  0.000000        0.5
# 1  0.10101  0.312033        0.5
# 2  0.20202  0.592908        0.5
# 3  0.30303  0.814576        0.5
# 4  0.40404  0.954902        0.5

# %%
fig= px.line(data,x='Time',y='Value',animation_frame='Frequency',
             range_y=[-1.5,1.5])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a9f41806-a5c3-47d0-86e9-1015ff42a955" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a9f41806-a5c3-47d0-86e9-1015ff42a955")) {                    Plotly.newPlot(                        "a9f41806-a5c3-47d0-86e9-1015ff42a955",                        [{"hovertemplate":"Frequency=0.5\u003cbr\u003eTime=%{x}\u003cbr\u003eValue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":[0.0,0.10101010101010101,0.20202020202020202,0.30303030303030304,0.40404040404040403,0.5050505050505051,0.6060606060606061,0.7070707070707071,0.8080808080808081,0.9090909090909091,1.0101010101010102,1.1111111111111112,1.2121212121212122,1.3131313131313131,1.4141414141414141,1.5151515151515151,1.6161616161616161,1.7171717171717171,1.8181818181818181,1.9191919191919191,2.0202020202020203,2.121212121212121,2.2222222222222223,2.323232323232323,2.4242424242424243,2.525252525252525,2.6262626262626263,2.727272727272727,2.8282828282828283,2.929292929292929,3.0303030303030303,3.131313131313131,3.2323232323232323,3.3333333333333335,3.4343434343434343,3.5353535353535355,3.6363636363636362,3.7373737373737375,3.8383838383838382,3.9393939393939394,4.040404040404041,4.141414141414141,4.242424242424242,4.343434343434343,4.444444444444445,4.545454545454545,4.646464646464646,4.747474747474747,4.848484848484849,4.94949494949495,5.05050505050505,5.151515151515151,5.252525252525253,5.353535353535354,5.454545454545454,5.555555555555555,5.656565656565657,5.757575757575758,5.858585858585858,5.959595959595959,6.0606060606060606,6.161616161616162,6.262626262626262,6.363636363636363,6.4646464646464645,6.565656565656566,6.666666666666667,6.767676767676767,6.8686868686868685,6.96969696969697,7.070707070707071,7.171717171717171,7.2727272727272725,7.373737373737374,7.474747474747475,7.575757575757575,7.6767676767676765,7.777777777777778,7.878787878787879,7.979797979797979,8.080808080808081,8.181818181818182,8.282828282828282,8.383838383838384,8.484848484848484,8.585858585858587,8.686868686868687,8.787878787878787,8.88888888888889,8.98989898989899,9.09090909090909,9.191919191919192,9.292929292929292,9.393939393939394,9.494949494949495,9.595959595959595,9.696969696969697,9.797979797979798,9.8989898989899,10.0],"xaxis":"x","y":[0.0,0.3120334456984871,0.5929079290546404,0.8145759520503357,0.9549022414440739,0.9998741276738751,0.9450008187146685,0.7957618405308323,0.5670598638627709,0.28173255684143006,-0.03172793349806786,-0.34202014332566866,-0.6181589862206053,-0.8325698546347713,-0.9638421585599419,-0.998867339183008,-0.9341478602651068,-0.7761464642917572,-0.5406408174555982,-0.2511479871810794,0.06342391965656492,0.3716624556603268,0.6427876096865391,0.8497254299495142,0.9718115683235418,0.9968547759519424,0.9223542941045816,0.7557495743542594,0.5136773915734072,0.22031053278654106,-0.09505604330418282,-0.4009305354066128,-0.6667690005162913,-0.8660254037844387,-0.9788024462147785,-0.9938384644612542,-0.909631995354519,-0.7345917086575339,-0.48619673610046904,-0.18925124436041,0.12659245357375007,0.4297949120891697,0.6900790114821109,0.8814533634475816,0.984807753012208,0.9898214418809329,0.8959937742913363,0.7126941713788632,0.45822652172741013,0.15800139597334906,-0.15800139597334784,-0.4582265217274091,-0.7126941713788623,-0.8959937742913358,-0.9898214418809322,-0.9848077530122086,-0.881453363447583,-0.690079011482113,-0.42979491208917237,-0.12659245357374954,0.18925124436041052,0.4861967361004695,0.7345917086575319,0.9096319953545178,0.993838464461254,0.9788024462147787,0.8660254037844385,0.6667690005162935,0.4009305354066155,0.09 ...

# %%
# moving bubble chart
#preparing the data
np.random.seed(42)
years= np.arange(2000,2021)
years
# Out:
# array([2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010,
#        2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020])

# %%
countries=['USA','FR','JP','UK']

# %%
data ={
    'Year': np.repeat(years, 4), # using years for 4 countries
    'Country': np.tile(countries,len(years)),
    'GDP': np.random.rand(len(years)* len(countries))* 50000 +10000,
    'Lifespane': np.random.rand(len(years)*len(countries))*30 +50,
    'Population': np.random.rand(len(years)* len(countries))*1000000+500000
}

df= pd.DataFrame(data)
df.head()
# Out:
#    Year Country           GDP  Lifespane    Population
# 0  2000     USA  28727.005942  59.329470  5.407751e+05
# 1  2000      FR  57535.715320  59.755500  1.090893e+06
# 2  2000      JP  46599.697091  71.888185  1.177564e+06
# 3  2000      UK  39932.924210  69.126724  5.165878e+05
# 4  2001     USA  17800.932022  76.616382  1.012093e+06

# %%
fig= px.scatter(df,x='GDP',y='Lifespane',animation_frame='Year',
             animation_group='Country',size='Population', color='Country',
             hover_name='Country', size_max=60, range_x=[0,60000],range_y=[40,90])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="072f640e-d4eb-40cd-a011-cf726fb3f239" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("072f640e-d4eb-40cd-a011-cf726fb3f239")) {                    Plotly.newPlot(                        "072f640e-d4eb-40cd-a011-cf726fb3f239",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eCountry=USA\u003cbr\u003eYear=2000\u003cbr\u003eGDP=%{x}\u003cbr\u003eLifespane=%{y}\u003cbr\u003ePopulation=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["USA"],"ids":["USA"],"legendgroup":"USA","marker":{"color":"#636efa","size":[540775.1415547639],"sizemode":"area","sizeref":409.16959854234597,"symbol":"circle"},"mode":"markers","name":"USA","orientation":"v","showlegend":true,"x":[28727.005942368123],"xaxis":"x","y":[59.329469651469864],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eCountry=FR\u003cbr\u003eYear=2000\u003cbr\u003eGDP=%{x}\u003cbr\u003eLifespane=%{y}\u003cbr\u003ePopulation=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["FR"],"ids":["FR"],"legendgroup":"FR","marker":{"color":"#EF553B","size":[1090892.9431882417],"sizemode":"area","sizeref":409.16959854234597,"symbol":"circle"},"mode":"markers","name":"FR","orientation":"v","showlegend":true,"x":[57535.71532049581],"xaxis":"x","y":[59.755499660802414],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eCountry=JP\u003cbr\u003eYear=2000\u003cbr\u003eGDP=%{x}\u003cbr\u003eLifespane=%{y}\u003cbr\u003ePopulation=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["JP"],"ids":["JP"],"legendgroup":"JP","marker":{"color":"#00cc96","size":[1177564.3618422826],"sizemode":"area","sizeref":409.16959854234597,"symbol":"circle"},"mode":"markers","name":"JP","orientation":"v","showlegend":true,"x":[46599.697090570255],"xaxis":"x","y":[71.88818535014192],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eCountry=UK\u003cbr\u003eYear=2000\u003cbr\u003eGDP=%{x}\u003cbr\u003eLifespane=%{y}\u003cbr\u003ePopulation=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["UK"],"ids":["UK"],"legendgroup":"UK","marker":{"color":"#ab63fa","size":[516587.8289278562],"sizemode":"area","sizeref":409.16959854234597,"symbol":"circle"},"mode":"markers","name":"UK","orientation":"v","showlegend":true,"x":[39932.92420985183],"xaxis":"x","y":[69.12672414065639],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444, ...
